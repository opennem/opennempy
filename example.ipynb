# %%
from opennempy import web_api

# %%
#load data for a particular time period and NEM region (in this case SA)
df_5, df_30 = web_api.load_data(d1=datetime.datetime(2018,3,4), d2 = datetime.datetime(2018,4,19), region='sa1')

# %%
#remove empty cols
df_5.dropna(axis=1, inplace=True)

# %%
df_30.head()
# Out:
#                      PRICE  TEMPERATURE  ROOFTOP_SOLAR
# 2018-03-04 00:30:00  62.22         17.9            0.0
# 2018-03-04 01:00:00  59.65         17.5            0.0
# 2018-03-04 01:30:00  60.60         18.0            0.0
# 2018-03-04 02:00:00  59.21         18.1            0.0
# 2018-03-04 02:30:00  56.07         18.2            0.0

# %%
df_5.head()
# Out:
#                       DEMAND  NETINTERCHANGE  BATTERY  DISTILLATE  GAS_CCGT  \
# 2018-03-04 00:05:00  1442.02           -2.51     20.2       -0.06    473.70
# 2018-03-04 00:10:00  1436.01           14.83     23.9       -0.03    476.57
# 2018-03-04 00:15:00  1395.63           43.27     -6.1       -0.03    475.98
# 2018-03-04 00:20:00  1373.62           56.93    -38.9       -0.03    466.62
# 2018-03-04 00:25:00  1411.29           19.12     15.3       -0.03    474.80
#
#                      GAS_OCGT  GAS_STEAM    WIND
# 2018-03-04 00:05:00       0.0     149.60  801.91
# 2018-03-04 00:10:00       0.0     121.26  812.66
# 2018-03-04 00:15:00       0.0     116.70  790.71
# 2018-03-04 00:20:00       0.0     122.47  791.69
# 2018-03-04 00:25:00       0.0     121.41  789.92

# %%
#load NSW
nsw_5, nsw_30 = web_api.load_data(d1=datetime.datetime(2018,3,5), d2 = datetime.datetime(2018,3,10), region='nsw1')

# %%
nsw_30.plot()

# %%
df_5.plot()

# %%
df_5.mean()
# Out:
# DEMAND            1353.735515
# NETINTERCHANGE     -49.873793
# BATTERY             -0.978465
# DISTILLATE           0.343244
# GAS_CCGT           391.934075
# GAS_OCGT            48.902212
# GAS_STEAM          215.159675
# WIND               592.422441
# dtype: float64
